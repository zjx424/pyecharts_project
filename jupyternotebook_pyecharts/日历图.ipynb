# %%
import datetime
import random

from pyecharts import options as opts
from pyecharts.charts import Calendar



begin = datetime.date(2017, 1, 1)
end = datetime.date(2017, 12, 31)
data = [
    [str(begin + datetime.timedelta(days=i)), random.randint(1000, 25000)]
    for i in range((end - begin).days + 1)
]

c = (
    Calendar()
    .add("", data, calendar_opts=opts.CalendarOpts(range_="2017"))
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Calendar-2017年微信步数情况"),
        visualmap_opts=opts.VisualMapOpts(
            max_=20000,
            min_=500,
            orient="horizontal",
            is_piecewise=True,
            pos_top="230px",
            pos_left="100px",
        ),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="b0a800bf09d4424ebb8975e604d180b1" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_b0a800bf09d4424ebb8975e604d180b1 = echarts.init(
#             document.getElementById('b0a800bf09d4424ebb8975e604d180b1'), 'white', {renderer: 'canvas'});
#         var option_b0a800bf09d4424ebb8975e604d180b1 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "coordinateSystem": "calendar",
#             "data": [
#                 [
#                     "2017-01-01",
#                     18646
#                 ],
#                 [
#                     "2017-01-02",
#                     16770
#                 ],
#                 [
#                     "2017-01-03",
#                     7634
#                 ],
#                 [
#                     "2017-01-04",
#                     16983
#                 ],
#                 [
#                     "2017-01-05",
#                     4278
#                 ],
#                 [
#                     "2017-01-06",
#                     11577
#                 ],
#                 [
#                     "2017-01-07",
#                     20897
#                 ],
#                 [
#                     "2017-01-08",
#                     13453
#                 ],
#                 [
#                     "2017-01-09",
#                     23425
#                 ],
#                 [
#                     "2017-01-10",
#                     24120
#                 ],
#                 [
#                     "2017-01-11",
#                     20369
#                 ],
#                 [
#                     "2017-01-12",
#                     23805
#                 ],
#                 [
#                     "2017-01-13",
#                     19759
#                 ],
#                 [
#                     "2017-01-14",
#                     6782
#                 ],
#                 [
#                     "2017-01-15",
#                     2052
#                 ],
#                 [
#                     "2017-01-16",
#                     14268
#                 ],
#                 [
#                     "2017-01-17",
#                     5788
#                 ],
#                 [
#                     "2017-01-18",
#                     14867
#                 ],
#                 [
#                     "2017-01-19",
#                     9961
#                 ],
#                 [
#                     "2017-01-20",
#                     16421
#                 ],
#                 [
#                     "2017-01-21",
#                     22806
#                 ],
#                 [
#                     "2017-01-22",
#                     2753
#                 ],
#                 [
#                     "2017-01-23",
#                     14010
#                 ],
#                 [
#                     "2017-01-24",
#                     5192
#                 ],
#                 [
#                     "2017-01-25",
#                     20517
#                 ],
#                 [
#                     "2017-01-26",
#                     3806
#                 ],
#                 [
#                     "2017-01-27",
#                     3227
#                 ],
#                 [
#                     "2017-01-28",
#                     20964
#                 ],
#                 [
#                     "2017-01-29",
#                     10277
#                 ],
#                 [
#                     "2017-01-30",
#                     18783
#                 ],
#                 [
#                     "2017-01-31",
#                     2543
#                 ],
#                 [
#                     "2017-02-01",
#                     13652
#                 ],
#                 [
#                     "2017-02-02",
#                     16548
#                 ],
#                 [
#                     "2017-02-03",
#                     5458
#                 ],
#                 [
#                     "2017-02-04",
#                     17178
#                 ],
#                 [
#                     "2017-02-05",
#                     13441
#                 ],
#                 [
#                     "2017-02-06",
#                     8050
#                 ],
#                 [
#                     "2017-02-07",
#                     19686
#                 ],
#                 [
#                     "2017-02-08",
#                     4314
#                 ],
#                 [
#                     "2017-02-09",
#                     16967
#                 ],
#                 [
#                     "2017-02-10",
#                     17820
#                 ],
#                 [
#                     "2017-02-11",
#                     16289
#                 ],
#                 [
#                     "2017-02-12",
#                     12508
#                 ],
#                 [
#                     "2017-02-13",
#                     8827
#                 ],
#                 [
#                     "2017-02-14",
#                     5161
#                 ],
#                 [
#                     "2017-02-15",
#                     8394
#                 ],
#                 [
#                     "2017-02-16",
#                     8636
#                 ],
#                 [
#                     "2017-02-17",
#                     12776
#                 ],
#                 [
#                     "2017-02-18",
#                     11672
#                 ],
#                 [
#                     "2017-02-19",
#                     19803
#                 ],
#                 [
#                     "2017-02-20",
#                     20147
#                 ],
#                 [
#                     "2017-02-21",
#                     22845
#                 ],
#                 [
#                     "2017-02-22",
#                     21714
#                 ],
#                 [
#                     "2017-02-23",
#                     23922
#                 ],
#                 [
#                     "2017-02-24",
#                     10418
#                 ],
#                 [
#                     "2017-02-25",
#                     24665
#                 ],
#                 [
#                     "2017-02-26",
#                     19623
#                 ],
#                 [
#                     "2017-02-27",
#                     15222
#                 ],
#                 [
#                     "2017-02-28",
#                     16077
#                 ],
#                 [
#                     "2017-03-01",
#                     4799
#                 ],
#                 [
#                     "2017-03-02",
#                     16905
#                 ],
#                 [
#                     "2017-03-03",
#                     16101
#                 ],
#                 [
#                     "2017-03-04",
#                     13685
#                 ],
#                 [
#                     "2017-03-05",
#                     5614
#                 ],
#                 [
#                     "2017-03-06",
#                     20246
#                 ],
#                 [
#                     "2017-03-07",
#                     10001
#                 ],
#                 [
#                     "2017-03-08",
#                     1458
#                 ],
#                 [
#                     "2017-03-09",
#                     21292
#                 ],
#                 [
#                     "2017-03-10",
#                     20955
#                 ],
#                 [
#                     "2017-03-11",
#                     20063
#                 ],
#                 [
#                     "2017-03-12",
#                     8474
#                 ],
