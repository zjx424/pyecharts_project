# %%
from pyecharts.charts.bar import Bar
bar=Bar()
bar.add(x_axis=["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"], y_axis=[5, 20, 36, 10, 75, 90], name="kissme")
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="36f147b7218540ba849b0b492ecf748f" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_36f147b7218540ba849b0b492ecf748f = echarts.init(document.getElementById('36f147b7218540ba849b0b492ecf748f'), 'light', {renderer: 'canvas'});
#
# var option_36f147b7218540ba849b0b492ecf748f = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
# ...
